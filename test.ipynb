# %%
import os 
import h5py

# %%
path = "/staff/antoine/Projects/TFFK/fybr_toolbox/test_scripts/self_sup_np"
files = os.listdir(path)

# %%
files
# Out:
# ['24-01-2023T180610.h5',
#  '24-01-2023T180710.h5',
#  '24-01-2023T180810.h5',
#  '24-01-2023T180910.h5',
#  '24-01-2023T181010.h5',
#  '24-01-2023T181110.h5',
#  '24-01-2023T181210.h5',
#  '24-01-2023T181310.h5',
#  '24-01-2023T181410.h5',
#  '24-01-2023T181510.h5',
#  '24-01-2023T181610.h5',
#  '24-01-2023T181710.h5',
#  '24-01-2023T181810.h5',
#  '24-01-2023T181910.h5',
#  '24-01-2023T182010.h5',
#  '24-01-2023T182110.h5',
#  '27-02-2023T102950.h5',
#  '27-02-2023T103050.h5',
#  '27-02-2023T103150.h5',
#  '27-02-2023T103250.h5',
#  '27-02-2023T103350.h5',
#  '27-02-2023T103450.h5',
#  '27-02-2023T103550.h5',
#  '27-02-2023T103650.h5',
#  '27-02-2023T103750.h5',
#  '27-02-2023T103850.h5',
#  '27-02-2023T103950.h5',
#  '27-02-2023T104050.h5',
#  '27-02-2023T104150.h5',
#  '27-02-2023T104250.h5',
#  '27-02-2023T104350.h5',
#  '27-02-2023T104450.h5',
#  '27-02-2023T104550.h5',
#  '27-02-2023T104650.h5',
#  '27-02-2023T104750.h5',
#  '27-02-2023T104850.h5',
#  '27-02-2023T104950.h5',
# ...

# %%
#file = h5py.File(os.path.join(path, files[0]), 'r')
file = h5py.File('/staff/antoine/Projects/TFFK/fybr_toolbox/test_scripts/self_sup_np/16-02-2023T080200.h5', 'r')
file.close()

# %%
file.keys()
# Out:
# <KeysViewHDF5 ['max_trace', 'mfr']>

# %%
file["mfr"][:].shape
# Out:
# (19, 270)

# %%
file["mfr"][:]
# Out:
# array([[        nan,         nan,         nan, ..., 36.59360227,
#         33.9932287 , 33.40299319],
#        [        nan,         nan,         nan, ..., 34.64220449,
#         33.2207722 , 32.00533708],
#        [        nan,         nan,         nan, ..., 33.78986106,
#         37.57186961, 35.69953474],
#        ...,
#        [        nan,         nan,         nan, ..., 31.77811297,
#         30.94224979, 33.92521409],
#        [        nan,         nan,         nan, ..., 34.10600327,
#         33.78756324, 32.51613404],
#        [        nan,         nan,         nan, ..., 32.49683446,
#         34.01380092, 33.9529221 ]])

# %%
file.shape
# Out:
# (29999,)
